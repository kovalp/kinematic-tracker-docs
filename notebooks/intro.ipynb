# %%
# !uv pip install kinematic-tracker -U
# Out:
# Using Python 3.14.2 environment at: /home/VICOMTECH/pkoval/programs/github/kovalp/kinematic-tracker-docs/.venv
# Resolved 6 packages in 395ms
# Prepared 6 packages in 30ms
# Installed 6 packages in 19ms
#  + association-quality-clavia==0.2.0
#  + binary-classification-ratios==0.3.0
#  + kinematic-tracker==15.7.1
#  + numpy==2.4.0
#  + opencv-python==4.11.0.86
#  + scipy==1.16.3

# %%
import kinematic_tracker
