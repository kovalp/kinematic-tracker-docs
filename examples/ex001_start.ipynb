# %%
from kinematic_tracker import NdKkfTracker

# %%
tracker = NdKkfTracker([3, 1], [2, 2])

# %%
tracker
# Out:
# NdKkfTracker(
#     Association(hungarian mahalanobis threshold 0.25 mah_pre_factor 1.0)
#     num_misses_max 3
#     num_det_min 3)
